# %% [markdown]
# # Dataset — Predictive Maintenance Aircraft Engine
#
# ## Objectif
# Ce dataset est utilisé pour faire de la **maintenance prédictive** sur des moteurs d’avion.
# L’objectif est de prédire le **nombre de cycles restants avant la panne** (*Remaining Useful Life*).
#
# ---
#
# ## Structure des données
#
# Le dataset est composé de **trois fichiers** :
#
# ### 1. PM_train.csv
# - Données d’entraînement
# - Chaque moteur est observé cycle après cycle
# - Un cycle correspond à une phase de fonctionnement
# - À chaque cycle, 21 capteurs sont mesurés
# - Les moteurs commencent avec une usure initiale différente (inconnue)
# - La dernière ligne de chaque moteur correspond à la panne
#
# ---
#
# ### 2. PM_test.csv
# - Même structure que les données d’entraînement
# - Les moteurs ne vont pas jusqu’à la panne
# - Le nombre de cycles restants est inconnu
#
# ---
#
# ### 3. PM_truth.csv
# - Contient la vraie valeur du nombre de cycles restants
# - Sert à évaluer les performances du modèle
#
# ---
#
# ## Nature du problème
# - Problème de **séries temporelles multivariées**
# - Chaque moteur correspond à une séquence temporelle
# - La variable cible est le **RUL** (Remaining Useful Life)
#
# ---
#
# ## Capteurs
# - Certains capteurs sont constants et peuvent être supprimés
# - D’autres varient légèrement autour de 0
# - Les capteurs physiques (température, pression, vitesse) sont les plus informatifs
#
# ---
#
# ## Enjeu data science
# Un modèle performant n’a de valeur que si ses résultats sont compréhensibles et exploitables pour la prise de décision.

# %%
import pandas as pd

# Chemin vers mes datasets
PATH_TO_DATA = r"C:\Users\natha\Documents\Projets\Python\Data Airline\archive"

# Chargement des datasets
train_df = pd.read_csv(f"{PATH_TO_DATA}\PM_train.csv")
test_df = pd.read_csv(f"{PATH_TO_DATA}\PM_test.csv")
truth_df = pd.read_csv(f"{PATH_TO_DATA}\PM_truth.csv")

# Affichage des données d'entrainement jusqu'à la panne
print("Train shape:", train_df.shape)
train_df.head()
# Out:
# Train shape: (20631, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
#
#      s20      s21
# 0  39.06  23.4190
# ...

# %%
# Affichage des données d'entrainement sans la panne
print("Test shape:", test_df.shape)
test_df.head()
# Out:
# Test shape: (13096, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003     100.0  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003     100.0  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001     100.0  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000     100.0  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000     100.0  518.67  642.51  1587.19  1401.92
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.72  2388.03  8125.55  8.4052  0.03  392  2388  100.0
# 1  14.62  ...  522.16  2388.06  8139.62  8.3803  0.03  393  2388  100.0
# 2  14.62  ...  521.97  2388.03  8130.10  8.4441  0.03  393  2388  100.0
# 3  14.62  ...  521.38  2388.05  8132.90  8.3917  0.03  391  2388  100.0
# 4  14.62  ...  522.15  2388.03  8129.54  8.4031  0.03  390  2388  100.0
#
#      s20      s21
# 0  38.86  23.3735
# ...

# %%
# Affichage des données de perfomance
print("Truth shape:", truth_df.shape)
truth_df.head()
# Out:
# Truth shape: (100, 2)
#    id  cycle
# 0   1    112
# 1   2     98
# 2   3     69
# 3   4     82
# 4   5     91

# %%
train_df.info()
train_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        20631 non-null  int64
#  1   cycle     20631 non-null  int64
#  2   setting1  20631 non-null  float64
#  3   setting2  20631 non-null  float64
#  4   setting3  20631 non-null  float64
#  5   s1        20631 non-null  float64
#  6   s2        20631 non-null  float64
#  7   s3        20631 non-null  float64
#  8   s4        20631 non-null  float64
#  9   s5        20631 non-null  float64
#  10  s6        20631 non-null  float64
#  11  s7        20631 non-null  float64
#  12  s8        20631 non-null  float64
#  13  s9        20631 non-null  float64
#  14  s10       20631 non-null  float64
#  15  s11       20631 non-null  float64
#  16  s12       20631 non-null  float64
#  17  s13       20631 non-null  float64
#  18  s14       20631 non-null  float64
# ...

# %%
test_df.info()
test_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13096 entries, 0 to 13095
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        13096 non-null  int64
#  1   cycle     13096 non-null  int64
#  2   setting1  13096 non-null  float64
#  3   setting2  13096 non-null  float64
#  4   setting3  13096 non-null  float64
#  5   s1        13096 non-null  float64
#  6   s2        13096 non-null  float64
#  7   s3        13096 non-null  float64
#  8   s4        13096 non-null  float64
#  9   s5        13096 non-null  float64
#  10  s6        13096 non-null  float64
#  11  s7        13096 non-null  float64
#  12  s8        13096 non-null  float64
#  13  s9        13096 non-null  float64
#  14  s10       13096 non-null  float64
#  15  s11       13096 non-null  float64
#  16  s12       13096 non-null  float64
#  17  s13       13096 non-null  float64
#  18  s14       13096 non-null  float64
# ...

# %%
truth_df.info()
truth_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      100 non-null    int64
#  1   cycle   100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB
#                id      cycle
# count  100.000000  100.00000
# mean    50.500000   75.52000
# std     29.011492   41.76497
# min      1.000000    7.00000
# 25%     25.750000   32.75000
# 50%     50.500000   86.00000
# 75%     75.250000  112.25000
# max    100.000000  145.00000

# %% [markdown]
# ## Etat des données
#
# Les données sont deja propres vu qu'aucune case n'est vide.
#
# Nous allons maintenant voir le nombre de moteur dans chaque test

# %%
print("Nombre de moteur de test avec usure")
train_df['id'].nunique()
# Out:
# Nombre de moteur de test avec usure
# 100

# %%
print("Nombre de moteur de test sans usure")
test_df['id'].nunique()
# Out:
# Nombre de moteur de test sans usure
# 100

# %% [markdown]
# Durée de vie des moteurs jusqu'à usure

# %%
train_df.groupby('id')['cycle'].max()
# Out:
# id
# 1      192
# 2      287
# 3      179
# 4      189
# 5      269
#       ...
# 96     336
# 97     202
# 98     156
# 99     185
# 100    200
# Name: cycle, Length: 100, dtype: int64

# %% [markdown]
# Durée de vie des moteurs sur lesquels le modèle sera utilisétrain_df.groupby('id')['cycle'].max()

# %%
test_df.groupby('id')['cycle'].max()
# Out:
# id
# 1       31
# 2       49
# 3      126
# 4      106
# 5       98
#       ...
# 96      97
# 97     134
# 98     121
# 99      97
# 100    198
# Name: cycle, Length: 100, dtype: int64

# %% [markdown]
# Visualisation de l'usure d'un moteur

# %%
import matplotlib.pyplot as plt

engine_1 = train_df[train_df['id'] == 1]

# 
# plt.plot(engine_1['cycle'], engine_1['s2'])
# plt.show()
sensors = [col for col in train_df.columns if 's' in col]

engine_1 = train_df[train_df['id'] == 1]

for sensor in sensors:
    plt.figure()
    plt.plot(engine_1['cycle'], engine_1[sensor])
    plt.title(sensor)
    plt.xlabel("Cycle")
    plt.ylabel(sensor)
    plt.show()

# %%
constant_cols = []

for col in train_df.columns:
    if train_df[col].nunique() == 1:
        constant_cols.append(col)

print(constant_cols)

train_df[sensors].std().sort_values()

#engine_1.set_index('cycle')[sensors].plot(figsize=(12,8))
#plt.show()
# Out:
# ['setting3', 's1', 's5', 's10', 's16', 's18', 's19']
# setting3    0.000000e+00
# s19         0.000000e+00
# s18         0.000000e+00
# s16         1.556432e-14
# s10         4.660829e-13
# s5          3.394700e-12
# s1          6.537152e-11
# setting2    2.930621e-04
# s6          1.388985e-03
# setting1    2.187313e-03
# s15         3.750504e-02
# s8          7.098548e-02
# s13         7.191892e-02
# s21         1.082509e-01
# s20         1.807464e-01
# s11         2.670874e-01
# s2          5.000533e-01
# s12         7.375534e-01
# s7          8.850923e-01
# s17         1.548763e+00
# s3          6.131150e+00
# s4          9.000605e+00
# s14         1.907618e+01
# s9          2.208288e+01
# dtype: float64

# %% [markdown]
# Variable cible qu'est le RUL (Remaining Useful Life)

# %%
train_df['RUL'] = train_df.groupby('id')['cycle'].transform('max') - train_df['cycle']
